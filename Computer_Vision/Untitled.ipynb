# %%
# !pip install torchvision==0.11.2
# Out:
# ^C

# %%
import warnings
warnings.filterwarnings('ignore')

from glob import glob
import pandas as pd
import numpy as np 
from tqdm import tqdm
import cv2

import os
import timm
import random

import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torchvision.transforms as transforms
from sklearn.metrics import f1_score, accuracy_score
import time


device = torch.device('cuda')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-c3b3396eeebc> in <module>
#       9
#      10 import os
# ---> 11 import timm
#      12 import random
#      13
#
# ~\anaconda3\lib\site-packages\timm\__init__.py in <module>
#       1 from .version import __version__
# ----> 2 from .models import create_model, list_models, is_model, list_modules, model_entrypoint, \
#       3     is_scriptable, is_exportable, set_scriptable, set_exportable, has_model_default_key, is_model_default_key, \
#       4     get_model_default_value, is_model_pretrained
#
# ~\anaconda3\lib\site-packages\timm\models\__init__.py in <module>
# ----> 1 from .beit import *
#       2 from .byoanet import *
#       3 from .byobnet import *
#       4 from .cait import *
#       5 from .coat import *
#
# ~\anaconda3\lib\site-packages\timm\models\beit.py in <module>
#      27 import torch.nn.functional as F
#      28
# ---> 29 from .helpers import build_model_with_cfg
#      30 from .layers import PatchEmbed, Mlp, DropPath, trunc_normal_
#      31 from .registry import register_model
#
# ~\anaconda3\lib\site-packages\timm\models\helpers.py in <module>
#      15
#      16 from .features import FeatureListNet, FeatureDictNet, FeatureHookNet
# ---> 17 from .fx_features import FeatureGraphNet
#      18 from .hub import has_hf_hub, download_cached_file, load_state_dict_from_hf
#      19 from .layers import Conv2dSame, Linear
#
# ~\anaconda3\lib\site-packages\timm\models\fx_features.py in <module>
#       8
#       9 try:
# ---> 10     from torchvision.models.feature_extraction import create_feature_extractor
#      11     has_fx_feature_extraction = True
#      12 except ImportError:
#
# ~\anaconda3\lib\site-packages\torchvision\__init__.py in <module>
#       4 from .extension import _HAS_OPS
#       5
# ----> 6 from torchvision import models
#       7 from torchvision import datasets
#       8 from torchvision import ops
#
# ~\anaconda3\lib\site-packages\torchvision\models\__init__.py in <module>
#       6 from .densenet import *
#       7 from .googlenet import *
# ----> 8 from .mobilenet import *
#       9 from .mnasnet import *
#      10 from .shufflenetv2 import *
#
# ~\anaconda3\lib\site-packages\torchvision\models\mobilenet.py in <module>
# ----> 1 from .mobilenetv2 import MobileNetV2, mobilenet_v2, __all__ as mv2_all
#       2 from .mobilenetv3 import MobileNetV3, mobilenet_v3_large, mobilenet_v3_small, __all__ as mv3_all
#       3
#       4 __all__ = mv2_all + mv3_all
#
# ~\anaconda3\lib\site-packages\torchvision\models\mobilenetv2.py in <module>
#       6 from torch import Tensor
#       7 from .._internally_replaced_utils import load_state_dict_from_url
# ----> 8 from ..ops.misc import ConvNormActivation
#       9 from ._utils import _make_divisible
#      10 from typing import Callable, Any, Optional, List
#
# ~\anaconda3\lib\site-packages\torchvision\ops\__init__.py in <module>
# ----> 1 from .boxes import nms, batched_nms, remove_small_boxes, clip_boxes_to_image, box_area, box_iou, generalized_box_iou, \
#       2     masks_to_boxes
#       3 from .boxes import box_convert
#       4 from .deform_conv import deform_conv2d, DeformConv2d
#       5 from .roi_align import roi_align, RoIAlign
#
# ~\anaconda3\lib\site-packages\torchvision\ops\boxes.py in <module>
#      69
#      70
# ---> 71 @torch.jit._script_if_tracing
#      72 def _batched_nms_coordinate_trick(
#      73     boxes: Tensor,
#
# AttributeError: module 'torch.jit' has no attribute '_script_if_tracing'

# %%
train_png = sorted(glob('train/*.png'))
test_png = sorted(glob('test/*.png'))

# %%
train_y = pd.read_csv("data/train_df.csv")

train_labels = train_y["label"]

label_unique = sorted(np.unique(train_labels))
label_unique = {key:value for key,value in zip(label_unique, range(len(label_unique)))}

train_labels = [label_unique[k] for k in train_labels]

# %%
def img_load(path):
    img = cv2.imread(path)[:,:,::-1]
    img = cv2.resize(img, (512, 512))
    return img

# %%
train_imgs = [img_load(m) for m in tqdm(train_png)]
test_imgs = [img_load(n) for n in tqdm(test_png)]
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 4277/4277 [02:32<00:00, 28.11it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2154/2154 [01:19<00:00, 27.12it/s]

# %%
class Custom_dataset(Dataset):
    def __init__(self, img_paths, labels, mode='train'):
        self.img_paths = img_paths
        self.labels = labels
        self.mode=mode
    def __len__(self):
        return len(self.img_paths)
    def __getitem__(self, idx):
        img = self.img_paths[idx]
        if self.mode=='train':
            augmentation = random.randint(0,2)
            if augmentation==1:
                img = img[::-1].copy()
            elif augmentation==2:
                img = img[:,::-1].copy()
        img = transforms.ToTensor()(img)
        if self.mode=='test':
            pass
        
        label = self.labels[idx]
        return img, label
    
class Network(nn.Module):
    def __init__(self):
        super(Network, self).__init__()
        self.model = timm.create_model('efficientnet_b0', pretrained=True, num_classes=88)
        
    def forward(self, x):
        x = self.model(x)
        return x

# %%
batch_size = 32
epochs = 25

# Train
train_dataset = Custom_dataset(np.array(train_imgs), np.array(train_labels), mode='train')
train_loader = DataLoader(train_dataset, shuffle=True, batch_size=batch_size)

# Test
test_dataset = Custom_dataset(np.array(test_imgs), np.array(["tmp"]*len(test_imgs)), mode='test')
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=batch_size)

# %%
def score_function(real, pred):
    score = f1_score(real, pred, average="macro")
    return score

model = Network().to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.CrossEntropyLoss()
scaler = torch.cuda.amp.GradScaler() 



best=0
for epoch in range(epochs):
    start=time.time()
    train_loss = 0
    train_pred=[]
    train_y=[]
    model.train()
    for batch in (train_loader):
        optimizer.zero_grad()
        x = torch.tensor(batch[0], dtype=torch.float32, device=device)
        y = torch.tensor(batch[1], dtype=torch.long, device=device)
        with torch.cuda.amp.autocast():
            pred = model(x)
        loss = criterion(pred, y)


        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        
        train_loss += loss.item()/len(train_loader)
        train_pred += pred.argmax(1).detach().cpu().numpy().tolist()
        train_y += y.detach().cpu().numpy().tolist()
        
    
    train_f1 = score_function(train_y, train_pred)

    TIME = time.time() - start
    print(f'epoch : {epoch+1}/{epochs}    time : {TIME:.0f}s/{TIME*(epochs-epoch-1):.0f}s')
    print(f'TRAIN    loss : {train_loss:.5f}    f1 : {train_f1:.5f}')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-17-b47c1df118f1> in <module>
#       3     return score
#       4
# ----> 5 model = Network().to(device)
#       6
#       7 optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in to(self, *args, **kwargs)
#     897         Yields:
#     898             (string, Parameter): Tuple containing the name and parameter
# --> 899
#     900         Example::
#     901
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _apply(self, fn)
#     568         return result
#     569
# --> 570     def __setstate__(self, state):
#     571         self.__dict__.update(state)
#     572         # Support loading old checkpoints that don't have the following attrs:
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _apply(self, fn)
#     568         return result
#     569
# --> 570     def __setstate__(self, state):
#     571         self.__dict__.update(state)
#     572         # Support loading old checkpoints that don't have the following attrs:
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _apply(self, fn)
#     591             if name in modules:
#     592                 return modules[name]
# --> 593         raise AttributeError("'{}' object has no attribute '{}'".format(
#     594             type(self).__name__, name))
#     595
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in convert(t)
#     895                 are direct members of this module.
#     896
# --> 897         Yields:
#     898             (string, Parameter): Tuple containing the name and parameter
#     899
#
# ~\anaconda3\lib\site-packages\torch\cuda\__init__.py in _lazy_init()
#     206             return
#     207         self.prev_idx = torch._C._cuda_getDevice()
# --> 208         if self.prev_idx != self.idx:
#     209             torch._C._cuda_setDevice(self.idx)
#     210         _lazy_init()
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
torch.__version__
# Out:
# '1.10.0+cpu'

# %%
torch.cuda.is_available()
# Out:
# False

# %%
conda list
# Out:
# # packages in environment at C:\Users\Seo\anaconda3:
# #
# # Name                    Version                   Build  Channel
# _ipyw_jlab_nb_ext_conf    0.1.0                    py38_0
# _py-xgboost-mutex         2.0                       cpu_0    anaconda
# absl-py                   1.0.0                    pypi_0    pypi
# adabelief-pytorch         0.2.0                    pypi_0    pypi
# adabelief-tf              0.2.0                    pypi_0    pypi
# alabaster                 0.7.12                     py_0
# albumentations            1.1.0                    pypi_0    pypi
# altair                    4.2.0                    pypi_0    pypi
# anaconda                  2020.11                  py38_0
# anaconda-client           1.7.2                    py38_0
# anaconda-navigator        1.10.0                   py38_0
# anaconda-project          0.8.4                      py_0
# appdirs                   1.4.4                    pypi_0    pypi
# argh                      0.26.2                   py38_0
# argon2-cffi               20.1.0           py38he774522_1
# asn1crypto                1.4.0                      py_0
# astor                     0.8.1                    pypi_0    pypi
# astroid                   2.4.2                    py38_0
# astropy                   4.0.2            py38he774522_0
# astunparse                1.6.3                    pypi_0    pypi
# async_generator           1.10                       py_0
# atomicwrites              1.4.0                      py_0
# attrs                     20.3.0             pyhd3eb1b0_0
# audioread                 2.1.9                    pypi_0    pypi
# autograd                  1.3                      pypi_0    pypi
# autograd-gamma            0.5.0                    pypi_0    pypi
# automat                   20.2.0                   pypi_0    pypi
# autopep8                  1.5.4                      py_0
# babel                     2.8.1              pyhd3eb1b0_0
# backcall                  0.2.0                      py_0
# backports                 1.0                        py_2
# backports-zoneinfo        0.2.1                    pypi_0    pypi
# backports.functools_lru_cache 1.6.1              pyhd3eb1b0_0
# backports.shutil_get_terminal_size 1.0.0                    py38_2
# backports.tempfile        1.0                        py_1
# backports.weakref         1.0.post1                  py_1
# bayesian-optimization     1.2.0                    pypi_0    pypi
# bcrypt                    3.2.0            py38he774522_0
# beautifulsoup4            4.9.3              pyhb0f4dca_0
# bitarray                  1.6.1            py38h2bbff1b_0
# bkcharts                  0.2                      py38_0
# blas                      1.0                         mkl
# bleach                    3.2.1                      py_0
# blinker                   1.4                      pypi_0    pypi
# blis                      0.7.6                    pypi_0    pypi
# blosc                     1.20.1               h7bd577a_0
# bokeh                     2.2.3                    py38_0
# boto                      2.49.0                   py38_0
# bottleneck                1.3.2            py38h2a96729_1
# branca                    0.4.2                    pypi_0    pypi
# brotlipy                  0.7.0           py38he774522_1000
# bs4                       0.0.1                    pypi_0    pypi
# bzip2                     1.0.8                he774522_0
# ca-certificates           2020.10.14                    0    anaconda
# cachetools                5.0.0                    pypi_0    pypi
# catalogue                 1.0.0                    pypi_0    pypi
# catboost                  1.0.4                    pypi_0    pypi
# certifi                   2020.6.20          pyhd3eb1b0_3
# cffi                      1.14.3           py38h7a1dbc1_0
# chardet                   3.0.4                 py38_1003
# chromedriver-autoinstaller 0.3.1                    pypi_0    pypi
# click                     7.1.2                      py_0
# cloudpickle               1.6.0                      py_0
# clyent                    1.2.2                    py38_1
# colorama                  0.4.4                      py_0
# colorlover                0.3.0                    pypi_0    pypi
# comtypes                  1.1.7                 py38_1001
# conda                     4.11.0           py38haa244fe_0    conda-forge
# conda-build               3.20.5                   py38_1
# conda-env                 2.6.0                         1
# conda-package-handling    1.7.2            py38h76e460a_0
# conda-verify              3.4.2                      py_1
# console_shortcut          0.1.1                         4
# constantly                15.1.0                   pypi_0    pypi
# contextlib2               0.6.0.post1                py_0
# cryptography              3.1.1            py38h7a1dbc1_0
# cssselect                 1.1.0                    pypi_0    pypi
# curl                      7.71.1               h2a8f88b_1
# cycler                    0.10.0                   py38_0
# cymem                     2.0.6                    pypi_0    pypi
# cython                    0.29.14                  pypi_0    pypi
# cytoolz                   0.11.0           py38he774522_0
# dask                      2.30.0                     py_0
# dask-core                 2.30.0                     py_0
# decorator                 4.4.2                      py_0
# defusedxml                0.6.0                      py_0
# diff-match-patch          20200713                   py_0
# distributed               2.30.1           py38haa95532_0
# docutils                  0.16                     py38_1
# efficientnet              1.1.1                    pypi_0    pypi
# emoji                     1.7.0                    pypi_0    pypi
# entrypoints               0.3                      py38_0
# et_xmlfile                1.0.1                   py_1001
# fastcache                 1.1.0            py38he774522_0
# feedparser                6.0.8                    pypi_0    pypi
# filelock                  3.0.12                     py_0
# flake8                    3.8.4                      py_0
# flask                     1.1.2                      py_0
# flatbuffers               2.0                      pypi_0    pypi
# folium                    0.12.1.post1             pypi_0    pypi
# formulaic                 0.2.4                    pypi_0    pypi
# freetype                  2.10.4               hd328e21_0
# fsspec                    0.8.3                      py_0
# funcy                     1.17                     pypi_0    pypi
# future                    0.18.2                   py38_1
# gast                      0.5.3                    pypi_0    pypi
# get_terminal_size         1.0.0                h38e98db_0
# gevent                    20.9.0           py38he774522_0
# gitdb                     4.0.9                    pypi_0    pypi
# glob2                     0.7                        py_0
# google-auth               2.6.0                    pypi_0    pypi
# google-auth-oauthlib      0.4.6                    pypi_0    pypi
# google-pasta              0.2.0                    pypi_0    pypi
# graphviz                  2.38                 hfd603c8_2
# greenlet                  0.4.17           py38he774522_0
# grpcio                    1.44.0                   pypi_0    pypi
# h11                       0.12.0                   pypi_0    pypi
# h2                        3.2.0                    pypi_0    pypi
# h5py                      2.10.0           py38h5e291fa_0
# hdf5                      1.10.4               h7ebc959_0
# heapdict                  1.0.1                      py_0
# hpack                     3.0.0                    pypi_0    pypi
# html5lib                  1.1                        py_0
# htmlmin                   0.1.12                   pypi_0    pypi
# huggingface-hub           0.4.0                    pypi_0    pypi
# hyperframe                5.2.0                    pypi_0    pypi
# hyperlink                 21.0.0                   pypi_0    pypi
# icc_rt                    2019.0.0             h0cc432a_1
# icu                       58.2                 ha925a31_3
# idna                      2.10                       py_0
# imageio                   2.9.0                      py_0
# imagesize                 1.2.0                      py_0
# imbalanced-learn          0.9.0                    pypi_0    pypi
# imblearn                  0.0                      pypi_0    pypi
# importlib-metadata        4.11.1                   pypi_0    pypi
# importlib-resources       5.4.0                    pypi_0    pypi
# importlib_metadata        2.0.0                         1
# incremental               21.3.0                   pypi_0    pypi
# iniconfig                 1.1.1                      py_0
# intel-openmp              2020.2                      254
# interface-meta            1.2.4                    pypi_0    pypi
# intervaltree              3.1.0                      py_0
# ipykernel                 5.3.4            py38h5ca1d4c_0
# ipython                   7.19.0           py38hd4e2768_0
# ipython_genutils          0.2.0                    py38_0
# ipywidgets                7.5.1                      py_1
# isort                     5.6.4                      py_0
# itemadapter               0.4.0                    pypi_0    pypi
# itemloaders               1.0.4                    pypi_0    pypi
# itsdangerous              1.1.0                      py_0
# jdcal                     1.4.1                      py_0
# jedi                      0.17.1                   py38_0
# jinja2                    2.11.2                     py_0
# jmespath                  0.10.0                   pypi_0    pypi
# joblib                    1.0.1                    pypi_0    pypi
# jpeg                      9b                   hb83a4c4_2
# jpype1                    1.3.0                    pypi_0    pypi
# json5                     0.9.5                      py_0
# jsonschema                3.2.0                      py_2
# jupyter                   1.0.0                    py38_7
# jupyter-contrib-core      0.3.3                    pypi_0    pypi
# jupyter-contrib-nbextensions 0.5.1                    pypi_0    pypi
# jupyter-highlight-selected-word 0.2.0                    pypi_0    pypi
# jupyter-latex-envs        1.4.6                    pypi_0    pypi
# jupyter-nbextensions-configurator 0.4.1                    pypi_0    pypi
# jupyter_client            6.1.7                      py_0
# jupyter_console           6.2.0                      py_0
# jupyter_core              4.6.3                    py38_0
# jupyterlab                2.2.6                      py_0
# jupyterlab_pygments       0.1.2                      py_0
# jupyterlab_server         1.2.0                      py_0
# keras                     2.8.0                    pypi_0    pypi
# keras-applications        1.0.8                    pypi_0    pypi
# keras-preprocessing       1.1.2                    pypi_0    pypi
# keyring                   21.4.0                   py38_1
# kiwisolver                1.3.0            py38hd77b12b_0
# konlpy                    0.6.0                    pypi_0    pypi
# krb5                      1.18.2               hc04afaa_0
# kss                       3.4                      pypi_0    pypi
# lazy-object-proxy         1.4.3            py38he774522_0
# libarchive                3.4.2                h5e25573_0
# libclang                  13.0.0                   pypi_0    pypi
# libcurl                   7.71.1               h2a8f88b_1
# libiconv                  1.15                 h1df5818_7
# liblief                   0.10.1               ha925a31_0
# libpng                    1.6.37               h2a8f88b_0
# librosa                   0.9.1                    pypi_0    pypi
# libsodium                 1.0.18               h62dcd97_0
#
# Note: you may need to restart the kernel to use updated packages.libspatialindex           1.9.3                h33f27b4_0
# libssh2                   1.9.0                h7a1dbc1_1
# libtiff                   4.1.0                h56a325e_1
# libxgboost                1.5.0                hd77b12b_1
# libxml2                   2.9.10               hb89e7f3_3
# libxslt                   1.1.34               he774522_0
# lifelines                 0.26.4                   pypi_0    pypi
# lightgbm                  3.3.2            py38h885f38d_0    conda-forge
# llvmlite                  0.34.0           py38h1a82afc_4
# locket                    0.2.0                    py38_1
# lxml                      4.6.1            py38h1350720_0
# lz4-c                     1.9.2                hf4a77e7_3
# lzo                       2.10                 he774522_2
# m2w64-gcc-libgfortran     5.3.0                         6
# m2w64-gcc-libs            5.3.0                         7
# m2w64-gcc-libs-core       5.3.0                         7
# m2w64-gmp                 6.1.0                         2
# m2w64-libwinpthread-git   5.0.0.4634.697f757               2
# mako                      1.1.6                    pypi_0    pypi
# markdown                  3.3.6                    pypi_0    pypi
# markupsafe                2.0.1                    pypi_0    pypi
# matplotlib                3.3.2                         0
# matplotlib-base           3.3.2            py38hba9282a_0
# mccabe                    0.6.1                    py38_1
# menuinst                  1.4.16           py38he774522_1
# missingno                 0.5.0                    pypi_0    pypi
# mistune                   0.8.4           py38he774522_1000
# mkl                       2020.2                      256
# mkl-service               2.3.0            py38hb782905_0
# mkl_fft                   1.2.0            py38h45dec08_0
# mkl_random                1.1.1            py38h47e9c7a_0
# mock                      4.0.2                      py_0
# more-itertools            8.6.0              pyhd3eb1b0_0
# mpmath                    1.1.0                    py38_0
# msgpack-python            1.0.0            py38h74a9793_1
# msys2-conda-epoch         20160418                      1
# multimethod               1.7                      pypi_0    pypi
# multipledispatch          0.6.0                    py38_0
# murmurhash                1.0.6                    pypi_0    pypi
# mysql-connector-python    8.0.28                   pypi_0    pypi
# navigator-updater         0.2.1                    py38_0
# nbclient                  0.5.1                      py_0
# nbconvert                 6.0.7                    py38_0
# nbformat                  5.0.8                      py_0
# nest-asyncio              1.4.2              pyhd3eb1b0_0
# networkx                  2.5                        py_0
# ngboost                   0.3.12                   pypi_0    pypi
# nltk                      3.5                        py_0
# nose                      1.3.7                    py38_2
# notebook                  6.1.4                    py38_0
# numba                     0.51.2           py38hf9181ef_1
# numexpr                   2.7.1            py38h25d0782_0
# numpy                     1.22.3                   pypi_0    pypi
# numpydoc                  1.1.0              pyhd3eb1b0_1
# oauthlib                  3.2.0                    pypi_0    pypi
# olefile                   0.46                       py_0
# opencv-python-headless    4.5.5.62                 pypi_0    pypi
# openpyxl                  3.0.5                      py_0
# openssl                   1.1.1h               he774522_0    anaconda
# opt-einsum                3.3.0                    pypi_0    pypi
# outcome                   1.1.0                    pypi_0    pypi
# packaging                 21.3                     pypi_0    pypi
# pandas                    1.1.3            py38ha925a31_0
# pandoc                    2.11                 h9490d1a_0
# pandocfilters             1.4.3            py38haa95532_1
# paramiko                  2.7.2                      py_0
# parmap                    1.5.3                    pypi_0    pypi
# parsel                    1.6.0                    pypi_0    pypi
# parso                     0.7.0                      py_0
# partd                     1.1.0                      py_0
# path                      15.0.0                   py38_0
# path.py                   12.5.0                        0
# pathlib2                  2.3.5                    py38_0
# pathtools                 0.1.2                      py_1
# patsy                     0.5.1                    py38_0
# pep8                      1.7.1                    py38_0
# pexpect                   4.8.0                    py38_0
# pickleshare               0.7.5                 py38_1000
# pillow                    8.0.1            py38h4fa10fc_0
# pip                       22.0.4                   pypi_0    pypi
# pkginfo                   1.6.1            py38haa95532_0
# plac                      1.1.3                    pypi_0    pypi
# plotly                    5.5.0                    pypi_0    pypi
# pluggy                    0.13.1                   py38_0
# ply                       3.11                     py38_0
# pooch                     1.6.0                    pypi_0    pypi
# powershell_shortcut       0.0.1                         3
# preshed                   3.0.6                    pypi_0    pypi
# priority                  1.3.0                    pypi_0    pypi
# prometheus_client         0.8.0                      py_0
# prompt-toolkit            3.0.8                      py_0
# prompt_toolkit            3.0.8                         0
# protego                   0.1.16                   pypi_0    pypi
# protobuf                  3.19.4                   pypi_0    pypi
# psutil                    5.7.2            py38he774522_0
# py                        1.9.0                      py_0
# py-lief                   0.10.1           py38ha925a31_0
# py-xgboost                1.5.0            py38haa95532_1
# pyarrow                   7.0.0                    pypi_0    pypi
# pyasn1                    0.4.8                    pypi_0    pypi
# pyasn1-modules            0.2.8                    pypi_0    pypi
# pycodestyle               2.6.0                      py_0
# pycosat                   0.6.3            py38he774522_0
# pycparser                 2.20                       py_2
# pycurl                    7.43.0.6         py38h7a1dbc1_0
# pydantic                  1.9.0                    pypi_0    pypi
# pydeck                    0.7.1                    pypi_0    pypi
# pydispatcher              2.0.5                    pypi_0    pypi
# pydocstyle                5.1.1                      py_0
# pydot                     1.4.1                    py38_0
# pyflakes                  2.2.0                      py_0
# pygments                  2.7.2              pyhd3eb1b0_0
# pylint                    2.6.0                    py38_0
# pympler                   1.0.1                    pypi_0    pypi
# pymysql                   1.0.2                    pypi_0    pypi
# pynacl                    1.4.0            py38h62dcd97_1
# pyodbc                    4.0.30           py38ha925a31_0
# pyopenssl                 19.1.0                     py_1
# pyparsing                 2.4.7                      py_0
# pyqt                      5.9.2            py38ha925a31_4
# pyreadline                2.1                      py38_1
# pyrsistent                0.17.3           py38he774522_0
# pysocks                   1.7.1                    py38_0
# pytables                  3.6.1            py38ha5be198_0
# pytest                    6.1.1                    py38_0
# python                    3.8.5                h5fd99cc_1
# python-dateutil           2.8.1                      py_0
# python-graphviz           0.16                     pypi_0    pypi
# python-jsonrpc-server     0.4.0                      py_0
# python-language-server    0.35.1                     py_0
# python-libarchive-c       2.9                        py_0
# python_abi                3.8                      2_cp38    conda-forge
# pytorch-ignite            0.4.8                    pypi_0    pypi
# pytorchtools              0.0.2                    pypi_0    pypi
# pytz                      2020.1                     py_0
# pytz-deprecation-shim     0.1.0.post0              pypi_0    pypi
# pywavelets                1.1.1            py38he774522_2
# pywin32                   227              py38he774522_1
# pywin32-ctypes            0.2.0                 py38_1000
# pywinpty                  0.5.7                    py38_0
# pyyaml                    5.3.1            py38he774522_1
# pyzmq                     19.0.2           py38ha925a31_1
# qdarkstyle                2.8.1                      py_0
# qt                        5.9.7            vc14h73c81de_0
# qtawesome                 1.0.1                      py_0
# qtconsole                 4.7.7                      py_0
# qtpy                      1.9.0                      py_0
# qudida                    0.0.4                    pypi_0    pypi
# querystring-parser        1.2.4                    pypi_0    pypi
# queuelib                  1.6.2                    pypi_0    pypi
# regex                     2020.10.15       py38he774522_0
# requests                  2.24.0                     py_0
# requests-oauthlib         1.3.1                    pypi_0    pypi
# resampy                   0.2.2                    pypi_0    pypi
# rope                      0.18.0                     py_0
# rsa                       4.8                      pypi_0    pypi
# rtree                     0.9.4            py38h21ff451_1
# ruamel_yaml               0.15.87          py38he774522_1
# sacremoses                0.0.49                   pypi_0    pypi
# scikit-image              0.17.2           py38h1e1f486_0
# scikit-learn              0.23.2           py38h47e9c7a_0
# scikit-surprise           1.1.1                    pypi_0    pypi
# scipy                     1.5.2            py38h14eb087_0
# scrapy                    2.5.0                    pypi_0    pypi
# seaborn                   0.11.0                     py_0
# selenium                  4.1.0                    pypi_0    pypi
# semver                    2.13.0                   pypi_0    pypi
# send2trash                1.5.0                    py38_0
# sentence-transformers     2.2.0                    pypi_0    pypi
# sentencepiece             0.1.96                   pypi_0    pypi
# service-identity          21.1.0                   pypi_0    pypi
# setuptools                50.3.1           py38haa95532_1
# sgmllib3k                 1.0.0                    pypi_0    pypi
# shap                      0.40.0                   pypi_0    pypi
# simplegeneric             0.8.1                    py38_2
# singledispatch            3.4.0.3                 py_1001
# sip                       4.19.13          py38ha925a31_0
# six                       1.15.0           py38haa95532_0
# slicer                    0.0.7                    pypi_0    pypi
# smart-open                5.2.1                    pypi_0    pypi
# smmap                     5.0.0                    pypi_0    pypi
# sniffio                   1.2.0                    pypi_0    pypi
# snowballstemmer           2.0.0                      py_0
# sortedcollections         1.2.1                      py_0
# sortedcontainers          2.2.2                      py_0
# soundfile                 0.10.3.post1             pypi_0    pypi
# soupsieve                 2.0.1                      py_0
# sphinx                    3.2.1                      py_0
# sphinxcontrib             1.0                      py38_1
# sphinxcontrib-applehelp   1.0.2                      py_0
# sphinxcontrib-devhelp     1.0.2                      py_0
# sphinxcontrib-htmlhelp    1.0.3                      py_0
# sphinxcontrib-jsmath      1.0.1                      py_0
# sphinxcontrib-qthelp      1.0.3                      py_0
# sphinxcontrib-serializinghtml 1.1.4                      py_0
# sphinxcontrib-websupport  1.2.4                      py_0
# spyder                    4.1.5                    py38_0
# spyder-kernels            1.9.4                    py38_0
# sqlalchemy                1.3.20           py38h2bbff1b_0
# sqlite                    3.33.0               h2a8f88b_0
# sqlparse                  0.4.2                    pypi_0    pypi
# srsly                     1.0.5                    pypi_0    pypi
# statsmodels               0.12.0           py38he774522_0
# streamlit                 1.8.1                    pypi_0    pypi
# surprise                  0.1                      pypi_0    pypi
# sympy                     1.6.2            py38haa95532_1
# tabulate                  0.8.9                    pypi_0    pypi
# tangled-up-in-unicode     0.1.0                    pypi_0    pypi
# tblib                     1.7.0                      py_0
# tenacity                  8.0.1                    pypi_0    pypi
# tensorboard               2.8.0                    pypi_0    pypi
# tensorboard-data-server   0.6.1                    pypi_0    pypi
# tensorboard-plugin-wit    1.8.1                    pypi_0    pypi
# tensorflow                2.8.0                    pypi_0    pypi
# tensorflow-addons         0.16.1                   pypi_0    pypi
# tensorflow-io-gcs-filesystem 0.24.0                   pypi_0    pypi
# termcolor                 1.1.0                    pypi_0    pypi
# terminado                 0.9.1                    py38_0
# testpath                  0.4.4                      py_0
# tf-estimator-nightly      2.8.0.dev2021122109          pypi_0    pypi
# thinc                     7.4.5                    pypi_0    pypi
# threadpoolctl             2.1.0              pyh5ca1d4c_0
# tifffile                  2020.10.1        py38h8c2d366_2
# timm                      0.5.4                    pypi_0    pypi
# tk                        8.6.10               he774522_0
# tokenizers                0.11.6                   pypi_0    pypi
# toml                      0.10.1                     py_0
# toolz                     0.11.1                     py_0
# torch                     1.10.0                   pypi_0    pypi
# torchvision               0.11.1                   pypi_0    pypi
# tornado                   6.0.4            py38he774522_1
# tqdm                      4.50.2                     py_0
# traitlets                 5.0.5                      py_0
# transformers              4.17.0                   pypi_0    pypi
# trio                      0.19.0                   pypi_0    pypi
# trio-websocket            0.9.2                    pypi_0    pypi
# twisted                   21.7.0                   pypi_0    pypi
# twisted-iocpsupport       1.0.2                    pypi_0    pypi
# typeguard                 2.13.3                   pypi_0    pypi
# typing_extensions         3.7.4.3                    py_0
# tzdata                    2022.1                   pypi_0    pypi
# tzlocal                   4.2                      pypi_0    pypi
# ujson                     4.0.1            py38ha925a31_0
# unicodecsv                0.14.1                   py38_0
# urllib3                   1.25.11                    py_0
# validators                0.18.2                   pypi_0    pypi
# vc                        14.1                 h0510ff6_4
# vs2015_runtime            14.16.27012          hf0eaf9b_3
# w3lib                     1.22.0                   pypi_0    pypi
# waitress                  2.1.0                    pypi_0    pypi
# wasabi                    0.9.0                    pypi_0    pypi
# watchdog                  0.10.3                   py38_0
# wcwidth                   0.2.5                      py_0
# webencodings              0.5.1                    py38_1
# websocket-client          1.3.1                    pypi_0    pypi
# werkzeug                  1.0.1                      py_0
# wget                      3.2                      pypi_0    pypi
# wheel                     0.35.1                     py_0
# widgetsnbextension        3.5.1                    py38_0
# win_inet_pton             1.1.0                    py38_0
# win_unicode_console       0.5                      py38_0
# wincertstore              0.2                      py38_0
# winpty                    0.4.3                         4
# wordcloud                 1.8.1                    pypi_0    pypi
# wrapt                     1.11.2           py38he774522_0
# wsproto                   1.0.0                    pypi_0    pypi
# xlrd                      1.2.0                      py_0
# xlsxwriter                1.3.7                      py_0
# xlwings                   0.20.8                   py38_0
# xlwt                      1.3.0                    py38_0
# xmltodict                 0.12.0                     py_0
# xz                        5.2.5                h62dcd97_0
# yaml                      0.2.5                he774522_0
# yapf                      0.30.0                     py_0
# zeromq                    4.3.2                ha925a31_3
# zict                      2.0.0                      py_0
# zipp                      3.4.0              pyhd3eb1b0_0
# zlib                      1.2.11               h62dcd97_4
# zope                      1.0                      py38_1
# zope.event                4.5.0                    py38_0
# zope.interface            5.1.2            py38he774522_0
# zstd                      1.4.5                h04227a9_0

# %%
pip install torch===1.5.0 torchvision===0.6.0 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.htmlNote: you may need to restart the kernel to use updated packages.
# Collecting torch===1.5.0
#   Downloading https://download.pytorch.org/whl/cu102/torch-1.5.0-cp38-cp38-win_amd64.whl (899.1 MB)
#      ------------------------------------ 899.1/899.1 MB 782.4 kB/s eta 0:00:00
# Collecting torchvision===0.6.0
#   Downloading https://download.pytorch.org/whl/cu102/torchvision-0.6.0-cp38-cp38-win_amd64.whl (1.2 MB)
#      ---------------------------------------- 1.2/1.2 MB 9.8 MB/s eta 0:00:00
# ERROR: Could not install packages due to an OSError: [WinError 5] 액세스가 거부되었습니다: 'C:\\Users\\Seo\\anaconda3\\Lib\\site-packages\\~orch\\lib\\asmjit.dll'
# Consider using the `--user` option or check the permissions.
# Requirement already satisfied: numpy in c:\users\seo\anaconda3\lib\site-packages (from torch===1.5.0) (1.22.3)
# Requirement already satisfied: future in c:\users\seo\anaconda3\lib\site-packages (from torch===1.5.0) (0.18.2)
# Requirement already satisfied: pillow>=4.1.1 in c:\users\seo\anaconda3\lib\site-packages (from torchvision===0.6.0) (8.0.1)
# Installing collected packages: torch, torchvision
#   Attempting uninstall: torch
#     Found existing installation: torch 1.10.0
#     Uninstalling torch-1.10.0:
#       Successfully uninstalled torch-1.10.0

# %%
model.eval()
f_pred = []

with torch.no_grad():
    for batch in (test_loader):
        x = torch.tensor(batch[0], dtype = torch.float32, device = device)
        with torch.cuda.amp.autocast():
            pred = model(x)
        f_pred.extend(pred.argmax(1).detach().cpu().numpy().tolist())

# %%
label_decoder = {val:key for key, val in label_unique.items()}

f_result = [label_decoder[result] for result in f_pred]

# %%
submission = pd.read_csv("data/sample_submission.csv")

submission["label"] = f_result

submission

# %%
submission.to_csv("baseline.csv", index = False)
